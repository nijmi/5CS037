# %% [markdown]
# Nijmi Bajracharya Id:2508912 Group:L5CG11

# %%
from google.colab import drive

# %%
time_data = [
(3.5, 2.0, 7.0), (5.0, 1.5, 6.5), (2.5, 3.0, 8.0),
(4.0, 2.0, 6.0), (1.5, 4.5, 9.0), (3.0, 2.5, 7.5),
(5.5, 1.0, 6.0), (2.0, 3.5, 8.5), (4.5, 2.0, 7.0),
(3.0, 3.0, 7.5), (6.0, 1.5, 6.0), (2.5, 4.0, 8.0),
(4.0, 2.5, 7.0), (5.0, 2.0, 6.5), (3.5, 2.5, 7.0)
]

# %%
#task1
low = []
moderate = []
high = []

for day in time_data:
    study = day[0]

    if study < 3:
        low.append(study)
    elif study <= 5:
        moderate.append(study)
    else:
        high.append(study)

print("Low:", low)
print("Moderate:", moderate)
print("High:", high)
# Out:
# Low: [2.5, 1.5, 2.0, 2.5]
# Moderate: [3.5, 5.0, 4.0, 3.0, 4.5, 3.0, 4.0, 5.0, 3.5]
# High: [5.5, 6.0]

# %%
#task2
print("Low days =", len(low))
print("Moderate days =", len(moderate))
print("High days =", len(high))
# Out:
# Low days = 4
# Moderate days = 9
# High days = 2

# %%
#task3
study_minutes = []

for day in time_data:
    study = day[0]
    minutes = study * 60
    study_minutes.append(minutes)

print(study_minutes)
# Out:
# [210.0, 300.0, 150.0, 240.0, 90.0, 180.0, 330.0, 120.0, 270.0, 180.0, 360.0, 150.0, 240.0, 300.0, 210.0]

# %%
#task4
study_hour = []
entertainment_hour = []
sleep_hour = []

for day in time_data:
    study_hour.append(day[0])
    entertainment_hour.append(day[1])
    sleep_hour.append(day[2])

avg_study = sum(study_hour) / len(study_hour)
avg_ent = sum(entertainment_hour) / len(entertainment_hour)
avg_sleep = sum(sleep_hour) / len(sleep_hour)

print("Average Study =", avg_study)
print("Average Entertainment =", avg_ent)
print("Average Sleep =", avg_sleep)
# Out:
# Average Study = 3.7
# Average Entertainment = 2.5
# Average Sleep = 7.166666666666667

# %%
#task5
import matplotlib.pyplot as plt

plt.scatter(study_hour, sleep_hour)
plt.title("Study vs Sleep")
plt.xlabel("Study Hours")
plt.ylabel("Sleep Hours")
plt.show()

# %%
#task6
nested_list = [1, [2, [3, 4], 5], 6, [7, 8]]
def sum(nested_list):
    total=0
    for i in nested_list:
        if isinstance(i,list):
            total+=sum(i)
        else:
            total+=i
    return total
print(sum(nested_list));
# Out:
# 36

# %%
#task7
def generate_permutations(s):
    if len(s)<=1:
        return [s]
    perms=set()
    for i in range(len(s)):
        first=s[i]
        last=s[:i]+s[1+i:]
        for p in generate_permutations(last):
            perms.add(first+p)
    return list(perms)
print(generate_permutations('abc'))
# Out:
# ['cab', 'bca', 'acb', 'abc', 'cba', 'bac']

# %%
directory_structure = {
"file1.txt": 200,
"file2.txt": 300,
"subdir1": {
"file3.txt": 400,
"file4.txt": 100
},
"subdir2": {
"subsubdir1": {
"file5.txt": 250
},
"file6.txt": 150
}
}

# %%
#task8
def calculate_directory_size(directory):
    total=0
    for key,value in directory.items():
        if isinstance(value,dict):
            total+=calculate_directory_size(value)
        else:
            total+=value
    return total
print(calculate_directory_size(directory_structure))
# Out:
# 1400

# %%
#task9
def longest_common_subsequence(s1, s2):
    m, n = len(s1), len(s2)
    dp = [[0]*(n+1) for _ in range(m+1)]

    for i in range(1, m+1):
        for j in range(1, n+1):
            if s1[i-1] == s2[j-1]:
                dp[i][j] = dp[i-1][j-1] + 1
            else:
                dp[i][j] = max(dp[i-1][j], dp[i][j-1])

    return dp[m][n]

s1 = "abcde"
s2 = "ace"
print(longest_common_subsequence(s1, s2))
# Out:
# 3

# %%
#task10
def knapsack(weights, values, capacity):
    n = len(weights)
    dp = [[0]*(capacity+1) for _ in range(n+1)]

    for i in range(1, n+1):
        for w in range(1, capacity+1):
            if weights[i-1] <= w:
                dp[i][w] = max(dp[i-1][w], dp[i-1][w - weights[i-1]] + values[i-1])
            else:
                dp[i][w] = dp[i-1][w]
    return dp[n][capacity]

weights = [1, 3, 4, 5]
values = [1, 4, 5, 7]
capacity = 7
print(knapsack(weights, values, capacity))
# Out:
# 9
